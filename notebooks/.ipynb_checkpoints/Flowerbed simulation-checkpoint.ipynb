# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
def Simulate(watering_ammount, threshold, current_val, condition):
    top = current_val + watering_ammount
    s = top
    S = [s]
    i = 0
    while(s > threshold):
        #condition = cond(i, 200)
        s -= 0.01*s*condition + (np.random.rand()-0.5)*0.03
        S.append(s)
        i+=1
    return (S)


def SimulatePeriod(watering_ammount, period, current_val):
    top = current_val + watering_ammount
    s = top
    S = [s]
    for i in range(period):
        #condition = cond(i, 200)
        s -= 0.01*s + (np.random.rand()-0.5)*0.03
        S.append(s)
        i+=1
    return (S)

# %%
threshold = 0.5
true_threshold = 0.1
current_val = 1
condition = 1
watering_ammount = 0.5

stream = []
T = [threshold]
for i in range(15):
    S = Simulate(watering_ammount, threshold, current_val, condition)
    current_val = S[-1] + watering_ammount
    T = np.concatenate([T, [threshold]*len(S)])
    if(threshold > true_threshold):
        threshold -= 0.2*threshold
    elif(threshold < true_threshold):
        threshold += 0.2*threshold
    
        
    stream = np.concatenate([stream, S])


fig, ax = plt.subplots(figsize = (15, 5))
ax.hlines(true_threshold, 0, len(stream), color = 'r', linestyles='dashed')
plt.plot(T)
ax.plot(stream)

# %%
def cond(i, T, period):
    con = T*np.sin(np.pi*i/period)**2 +0.5
    return(con)

def SimulateSteps(watering_ammount, current_val, T):
    top = current_val + watering_ammount
    s = top
    S = np.linspace(current_val, top, 5)
    for i in range(300):
        condition = cond(i, T,  1000)
        s -= 0.003*s + 0.03*s*(np.random.rand()-0.5)
        S = np.concatenate([S, [s]])
        
    return (S)

plt.plot(SimulateSteps(45,0, 1))
plt.ylim([-10, 50])
plt.xlim([-10, 1000])

# %%
x_train = []
y_train = []

for i in range(1000):
    WA = 100*np.random.rand()
    current = 100*np.random.rand()
    T = 1
    x_train.append([WA, current, T])
    y_train.append(SimulateSteps(WA, current, T))
    
x_train = np.array(x_train)
y_train = np.array(y_train)
print(x_train[0])
print(y_train[0])

# %%
x_train = []
y_train = []
lens = []
Len = 80
for i in ['flowerbed2.npy', 'flowerbed3.npy', 'flowerbed7.npy', 'flowerbed8.npy']:
    data = np.load(i,allow_pickle = True)
    print(len(data))
    #plt.plot(data[0][0])
    #print(data[0][2])

    for j in range(len(data)):
        if(len(data[j][0]) >Len):
            
            #while(len(data[j][0])<Len):
            #    data[j][0] = np.append(data[j][0], data[j][0][-1])
                
            
            for k in range(len(data[j][0])-Len):
                if(k<5):
                    y_train.append(np.array(data[j][0][1 + k:Len + k]))
                #(series, trenutna, temp, čas?)
                    x_train.append([data[j][0][1 + k], data[j][2], datetime.fromtimestamp(data[j][1][0]).hour])
                    if(np.isnan(data[j][0][0])):
                        y_train = y_train[:-1]
                        x_train = x_train[:-1]
            
            #data[j][2] -- temperatura!
            #x_train.append([data[j][0][0], data[j][2], datetime.fromtimestamp(data[j][1][0]).hour])
                    lens.append(len(y_train[-1]))
        

x_train = np.array(x_train)
y_train = np.array(y_train)
#print(x_train.shape)
#print(y_train.shape)

d = np.array([0, 0], dtype = object)
d[0] = x_train
d[1] = y_train

#np.save('train_data_carouge.npy', d)

x_train /= 30
y_train /= 30          
#for i in range(len(y_train)):
#    plt.plot(y_train[i])
#print(lens) 
#print(str(len(x_train)) + ' samples')

shuffler = np.random.permutation(len(x_train))
x_train = x_train[shuffler]
y_train = y_train[shuffler]
print(x_train)

# %%
y_train, x_train = np.load(f'flowerbed8_160h_new.npy', allow_pickle = True)
for n in []:
    data = np.load(f'flowerbed{n}_160h_new.npy', allow_pickle = True)
    yy_train, xx_train = data
    x_train = np.concatenate([x_train, xx_train], axis = 0)
    y_train = np.concatenate([y_train, yy_train], axis = 0)

shuffler = np.random.permutation(len(x_train))
x_train = x_train[shuffler]
y_train = y_train[shuffler]

y_train = y_train
x_train = x_train




#x_train = np.asarray(x_train).astype('float32')
#y_train = np.asarray(y_train).astype('float32')
print(len(x_train))

plt.hist(y_train[:,0]*30, bins = 50)
plt.show()

# %%
Len = 80
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(7,activation='relu'))
model.add(tf.keras.layers.Dense(100))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(200, activation='tanh'))
model.add(tf.keras.layers.Dropout(0.2))
#model.add(tf.keras.layers.Dense(50, activation='tanh'))

model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(Len, activation='relu'))

model.compile(optimizer =tf.keras.optimizers.Adam(lr = 0.001, beta_1 = 0.99), loss = 'mse')

batch_size = 50
history = model.fit(x_train[10:][:, :7],y_train[10:], epochs =300, batch_size = batch_size, validation_data = (x_train[:10][:, :7], y_train[:10]), verbose = 1)

plt.plot(history.history['loss'])
plt.yscale('log')

# %%
plt.hist(y_train[:,0]*30, bins = 50)
plt.show()

# %%
for test in [4, 5, 6, 7, 8, 9]:
    #print(y_rain[test])
    #print(x_train[test])
    y_pred = model.predict(np.atleast_2d(x_train[test][:7]))

    y_pred[0] = np.add(y_pred[0], (+y_train[test][0] - y_pred[0][0]))
    print(30*y_pred[0][-1] - 30*y_pred[0][0])
    #print(y_pred)

    plt.plot(30*y_pred[0], label = 'prediction')
    plt.plot(30*y_train[test], label = 'true')
    #plt.legend()
    #plt.ylim([15, 35])

#plt.ylim([20, 30])
#print(x_train[test])
plt.xlabel('intervals')
plt.ylabel('moisture[%]')
#plt.legend()
#plt.ylim([24, 25])

# %%
y_pred = model.predict(np.atleast_2d(x_train[:,:7]))
len(y_pred)

errs_7 = []
for i, j in zip(y_pred, y_train):
    errs_7.append(mse(i, j))
y_7 = y_train[:,0]

# %%
plt.scatter(y_7*30, errs_7, label = '7')
plt.scatter(y_2*30, errs_2)
plt.xlabel(r'$T_0$')
plt.ylabel('prediction mse')
plt.legend()

# %%
#simulation of feedback looop and forecasting combined

Period = 150           #period of plant watering
current_dampness = 1.5 #starting dampness
true_th = 0.3          #true threshold -> if we miss it we get feedback to correct the estimated threshold
estimated_th = 1.2     #starting estimation is higher than the true threshold
num_cycles = 60        #number of periods to simulate

S = []
thresholds = []
WAs = []
fig, ax = plt.subplots(figsize = (15, 5))

errors = []           #track forecast errors

for i in range(num_cycles):
    T = 1
    Ts = []
    for j in np.linspace(0.3, 2.5, 20):
        #forecasts for different WA
        y_pred = model.predict(np.atleast_2d([j, current_dampness, T]))[0]
        t = len(y_pred[y_pred>=estimated_th])
        Ts.append(t)
     
    #Choose the WA, which reaches the threshold closest to the target time
    WA = np.linspace(0.3, 2.5, 20)[np.argmin(np.abs(np.array(Ts) - Period))]
    WAs.append(WA)
    
    #simulate the chosen WA
    S = np.concatenate([S, SimulateSteps(WA, current_dampness, T)[:Period]])
    
    current_dampness = S[-1]
    thresholds = np.append(thresholds, np.repeat(estimated_th, Period))
    
    errors.append(S[-1] - estimated_th)
    
    #correct the estimated threshold based on the feedback info
    if(S[-1] > true_th):
        estimated_th = S[-1]*0.9
    else:
        estimated_th = S[-1]*1.1

ax.plot(thresholds, label = 'threshold')
ax.plot(S, label = 'dampness')
ax.set_xlabel('time')
ax.hlines(true_th, 0, 9000, color = 'r', linestyle = '--')
plt.legend()

# %%
def mse(x, y):
    err = np.sum(np.add(np.array(x), -np.array(y))**2)/len(x)
    return(err)

# %%
for i, sample in enumerate(y_train):
    
    if(max(sample)<0.75):
        print(i)
        plt.plot(sample)

# %%
Loss = lambda WA, time: 0.1*WA/0.093 - 1*time

current_dampness = 5
estimated_th = 20

WAs = np.linspace(0, 50, 50)
Times = []
Losses = []

#Get the loss for all possible watering ammounts
for i in WAs:
    test = x_train[0][:7]
    test[0] = (i + current_dampness)/30
    y_pred = model.predict(np.atleast_2d(test))[0]*30
    
    y_pred = np.add(y_pred, test[0]*30 - y_pred[0])
    
    #plt.plot(y_pred)
    t = len(y_pred[y_pred>=estimated_th])*2
    Times.append(t)
    print(i, t)
    print(Loss(i, t))
    Losses.append(Loss(i, t))
    
plt.plot(WAs, Losses)

#choose the minimal loss        
idx = np.argmin(Losses)
WA = WAs[idx]
time = Times[idx]

print("WA: " + str(WA))
print("time: " + str(time))

#y_pred = model.predict(np.atleast_2d([WA, current_dampness, T]))
#plt.plot(y_pred[0][:time], label = 'prediction')
#plt.plot(SimulateSteps(WA, current_dampness, T)[:time], label = 'true')
#plt.legend()

# %%
x_train, y_train = np.load('train_data_carouge_weather.npy', allow_pickle = True)
x_train.shape

# %%
d = np.array([0, 0], dtype = object)
d[0] = x_train[:,:7]
d[1] = y_train

np.save('train_data_carouge_updated.npy',d, allow_pickle = True)
